# %%
import pandas as pd
import numpy as np
import tqdm

# %%
#last, first, min, max,std,mean,median
importnant_columns = ['customer_ID', 'S_2',
                      'P_2', 'P_3',
                      'D_39', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48','D_49', 'D_62', 'D_75', 'D_104', 'D_141',
                      'B_2', 'B_3', 'B_4', 'B_8', 'B_9', 'B_18', 'B_11', 'B_23', 'B_33',
                      'R_1', 'R_27',
                      'S_3', 'S_25',
                     "B_30","B_38","D_114","D_117","D_120","D_64","D_68",
                      'target']

# %%
train = pd.read_pickle(r'C:\Users\domin\Downloads\AE_pickled\train.pkl')[importnant_columns]
stat_list = ['first', 'last', 'median', 'mean', 'std', 'max']
#test = pd.read_pickle(r'C:\Users\domin\Downloads\AE_pickled\test.pkl')

# %%
def number_cat(list_of_categories):
    """Function to cast categorical vatriables as numeric, output - dictionary of mappings"""
    unique_values = list_of_categories.values.unique()
    corresponding_map = {}
    i = 0
    for q in unique_values:
        corresponding_map[q] = i
        i +=1
    return corresponding_map

# %%
mapping = number_cat(train['D_64'])
train['D_64'] = [mapping[q] for q in train['D_64']]

# %%
def process_and_feature_engineer(df):
    # FEATURE ENGINEERING FROM 
    # https://www.kaggle.com/code/huseyincot/amex-agg-data-how-it-created
    all_cols = [c for c in list(df.columns) if c not in ['customer_ID','S_2']]
    cat_features = ["B_30","B_38","D_114","D_117","D_120","D_64","D_68"]
    num_features = [x for x in importnant_columns if x not in cat_features]

    test_num_agg = df.groupby("customer_ID")[num_features].agg(['mean', 'sem', 'min', 'max', 'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]

    test_cat_agg = df.groupby("customer_ID")[cat_features].agg(['first', 'last', 'nunique', 'diff'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]
    df = pd.concat([test_num_agg, test_cat_agg], axis=1)
    del test_num_agg, test_cat_agg
    print('shape after engineering', df.shape )
    print(df.columns)
    return df
train_processed = process_and_feature_engineer(train)
# Out:
# shape after engineering (5990364, 173)
# Index(['P_2_mean', 'P_2_sem', 'P_2_min', 'P_2_max', 'P_2_last', 'P_3_mean',
#        'P_3_sem', 'P_3_min', 'P_3_max', 'P_3_last',
#        ...
#        'D_120_nunique', 'D_120_diff', 'D_64_first', 'D_64_last',
#        'D_64_nunique', 'D_64_diff', 'D_68_first', 'D_68_last', 'D_68_nunique',
#        'D_68_diff'],
#       dtype='object', length=173)

# %%
for col in train_processed.columns: print(col)
# Out:
# P_2_mean
# P_2_sem
# P_2_min
# P_2_max
# P_2_last
# P_3_mean
# P_3_sem
# P_3_min
# P_3_max
# P_3_last
# D_39_mean
# D_39_sem
# D_39_min
# D_39_max
# D_39_last
# D_42_mean
# D_42_sem
# D_42_min
# D_42_max
# D_42_last
# D_43_mean
# D_43_sem
# D_43_min
# D_43_max
# D_43_last
# D_44_mean
# D_44_sem
# D_44_min
# D_44_max
# D_44_last
# D_45_mean
# D_45_sem
# D_45_min
# D_45_max
# D_45_last
# D_46_mean
# D_46_sem
# D_46_min
# D_46_max
# D_46_last
# D_47_mean
# D_47_sem
# D_47_min
# D_47_max
# D_47_last
# D_48_mean
# D_48_sem
# D_48_min
# D_48_max
# D_48_last
# D_49_mean
# D_49_sem
# D_49_min
# D_49_max
# D_49_last
# D_62_mean
# D_62_sem
# D_62_min
# D_62_max
# D_62_last
# D_75_mean
# D_75_sem
# D_75_min
# D_75_max
# D_75_last
# D_104_mean
# D_104_sem
# D_104_min
# D_104_max
# D_104_last
# D_141_mean
# D_141_sem
# D_141_min
# D_141_max
# D_141_last
# B_2_mean
# B_2_sem
# B_2_min
# B_2_max
# B_2_last
# B_3_mean
# B_3_sem
# B_3_min
# B_3_max
# B_3_last
# B_4_mean
# B_4_sem
# B_4_min
# B_4_max
# B_4_last
# B_8_mean
# B_8_sem
# B_8_min
# B_8_max
# B_8_last
# B_9_mean
# B_9_sem
# B_9_min
# B_9_max
# B_9_last
# B_18_mean
# B_18_sem
# B_18_min
# B_18_max
# B_18_last
# B_11_mean
# B_11_sem
# B_11_min
# B_11_max
# B_11_last
# B_23_mean
# B_23_sem
# B_23_min
# B_23_max
# B_23_last
# B_33_mean
# B_33_sem
# B_33_min
# B_33_max
# B_33_last
# R_1_mean
# R_1_sem
# R_1_min
# R_1_max
# R_1_last
# R_27_mean
# R_27_sem
# R_27_min
# R_27_max
# R_27_last
# S_3_mean
# S_3_sem
# S_3_min
# S_3_max
# S_3_last
# S_25_mean
# S_25_sem
# S_25_min
# S_25_max
# S_25_last
# target_mean
# target_sem
# target_min
# target_max
# target_last
# B_30_first
# B_30_last
# B_30_nunique
# B_30_diff
# B_38_first
# B_38_last
# B_38_nunique
# B_38_diff
# D_114_first
# D_114_last
# D_114_nunique
# D_114_diff
# D_117_first
# D_117_last
# D_117_nunique
# D_117_diff
# D_120_first
# D_120_last
# D_120_nunique
# D_120_diff
# D_64_first
# D_64_last
# D_64_nunique
# D_64_diff
# D_68_first
# D_68_last
# D_68_nunique
# D_68_diff

# %%
targets = train[['customer_ID', 'target']].drop_duplicates().set_index('customer_ID')
targets
# Out:
#                                                     target
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...       0
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...       0
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...       0
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...       0
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...       0
# ...                                                    ...
# ffff41c8a52833b56430603969b9ca48d208e7c192c6a40...       0
# ffff518bb2075e4816ee3fe9f3b152c57fc0e6f01bf7fdd...       0
# ffff9984b999fccb2b6127635ed0736dda94e544e67e026...       0
# ffffa5c46bc8de74f5a4554e74e239c8dee6b9baf388145...       1
# fffff1d38b785cef84adeace64f8f83db3a0c31e8d92eab...       0
#
# [458913 rows x 1 columns]

# %%
train_processed = train_processed.merge(targets, how = 'left', left_index = True, right_index = True)

# %%
train_processed
# Out:
#                                                     P_2_mean   P_2_sem  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.933594  0.006710
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.899902  0.006129
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.878418  0.007998
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.599121  0.005570
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.891602  0.011736
# ...                                                      ...       ...
# 5531446                                                  NaN       NaN
# 5531447                                                  NaN       NaN
# 5531448                                                  NaN       NaN
# 5531449                                                  NaN       NaN
# 5531450                                                  NaN       NaN
#
#                                                      P_2_min   P_2_max  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.868652  0.960449
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.861328  0.929199
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.797852  0.904297
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.567383  0.623535
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.805176  0.940430
# ...                                                      ...       ...
# 5531446                                                  NaN       NaN
# 5531447                                                  NaN       NaN
# 5531448                                                  NaN       NaN
# 5531449                                                  NaN       NaN
# 5531450                                                  NaN       NaN
#
#                                                     P_2_last  P_3_mean  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.934570  0.680176
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.880371  0.566895
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.880859  0.618164
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.621582  0.610840
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.872070  0.527344
# ...                                                      ...       ...
# 5531446                                                  NaN       NaN
# 5531447                                                  NaN       NaN
# 5531448                                                  NaN       NaN
# 5531449                                                  NaN       NaN
# 5531450                                                  NaN       NaN
#
#                                                      P_3_sem   P_3_min  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.014058  0.581543
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.010224  0.510254
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.020972  0.381104
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.024979  0.345215
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.024542  0.254395
# ...                                                      ...       ...
# 5531446                                                  NaN       NaN
# 5531447                                                  NaN       NaN
# 5531448                                                  NaN       NaN
# 5531449                                                  NaN       NaN
# 5531450                                                  NaN       NaN
#
#                                                      P_3_max  P_3_last  ...  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  0.741699  0.629395  ...
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...  0.619141  0.570801  ...
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...  0.678711  0.628906  ...
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...  0.704102  0.671875  ...
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...  0.584473  0.570312  ...
# ...                                                      ...       ...  ...
# 5531446                                                  NaN       NaN  ...
# 5531447                                                  NaN       NaN  ...
# 5531448                                                  NaN       NaN  ...
# 5531449                                                  NaN       NaN  ...
# 5531450                                                  NaN       NaN  ...
#
#                                                     D_120_diff  D_64_first  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...         NaN         0.0
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...         NaN         0.0
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...         NaN         1.0
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...         NaN         0.0
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...         NaN         0.0
# ...                                                        ...         ...
# 5531446                                                    0.0         NaN
# 5531447                                                    0.0         NaN
# 5531448                                                    0.0         NaN
# 5531449                                                    0.0         NaN
# 5531450                                                    0.0         NaN
#
#                                                     D_64_last  D_64_nunique  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...        0.0           1.0
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...        0.0           1.0
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...        1.0           1.0
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...        0.0           1.0
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...        0.0           1.0
# ...                                                       ...           ...
# 5531446                                                   NaN           NaN
# 5531447                                                   NaN           NaN
# 5531448                                                   NaN           NaN
# 5531449                                                   NaN           NaN
# 5531450                                                   NaN           NaN
#
#                                                     D_64_diff  D_68_first  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...        NaN         6.0
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...        NaN         6.0
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...        NaN         6.0
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...        NaN         2.0
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...        NaN         6.0
# ...                                                       ...         ...
# 5531446                                                   0.0         NaN
# 5531447                                                   0.0         NaN
# 5531448                                                   0.0         NaN
# 5531449                                                   0.0         NaN
# 5531450                                                   0.0         NaN
#
#                                                     D_68_last  D_68_nunique  \
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...        6.0           1.0
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...        6.0           1.0
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...        6.0           1.0
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...        3.0           3.0
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...        6.0           1.0
# ...                                                       ...           ...
# 5531446                                                   NaN           NaN
# 5531447                                                   NaN           NaN
# 5531448                                                   NaN           NaN
# 5531449                                                   NaN           NaN
# 5531450                                                   NaN           NaN
#
#                                                     D_68_diff  target
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...        NaN     0.0
# 00000fd6641609c6ece5454664794f0340ad84dddce9a26...        NaN     0.0
# 00001b22f846c82c51f6e3958ccd81970162bae8b007e80...        NaN     0.0
# 000041bdba6ecadd89a52d11886e8eaaec9325906c97233...        NaN     0.0
# 00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8ad...        NaN     0.0
# ...                                                       ...     ...
# 5531446                                                   0.0     NaN
# 5531447                                                   0.0     NaN
# 5531448                                                   0.0     NaN
# 5531449                                                   0.0     NaN
# 5531450                                                   0.0     NaN
#
# [5990364 rows x 174 columns]

# %%
len(train_processed)
# Out:
# 5990364

# %%
train_processed.to_pickle('test_correct.pkl')
